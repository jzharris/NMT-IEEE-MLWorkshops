# %% [markdown]
# # Import Stuff

# %%
from math import sqrt
from numpy import concatenate
from matplotlib import pyplot
import pandas as pd
from datetime import datetime
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import mean_squared_error
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
import plotly.offline as py
import plotly.graph_objs as go
import numpy as np
import seaborn as sns
py.init_notebook_mode(connected=True)
# %matplotlib inline
# %matplotlib notebook
# Out:
# Using TensorFlow backend.
# <script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window.Plotly) {{require(['plotly'],function(plotly) {window.Plotly=plotly;});}}</script>

# %%
data = pd.read_csv("merged_data.csv")

# %%
btc_trace = go.Scatter(x=data['Time'], y=data['Price'], name= 'Price')
py.iplot([btc_trace])
# Out:
# <div id="65ac7c72-4b93-4d26-836a-54afb58b853a" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("65ac7c72-4b93-4d26-836a-54afb58b853a", [{"type": "scatter", "y": [14565.4, 14565.4, 14565.4, 14565.4, 14565.4, 14565.4, 14565.4, 14565.4, 14565.4, 14565.4, 14565.4, 14565.4, 14565.4, 14565.4, 14565.4, 14565.4, 14565.4, 14565.4, 14565.4, 14565.4, 14529.0, 14529.0, 14529.0, 14529.0, 14529.0, 14529.0, 14529.0, 14529.0, 14529.0, 14529.0, 14529.0, 14529.0, 14529.0, 14529.0, 14529.0, 14529.0, 14529.0, 14529.0, 14529.0, 14529.0, 14407.7, 14407.7, 14407.7, 14407.7, 14407.7, 14407.7, 14407.7, 14407.7, 14407.7, 14407.7, 14407.7, 14407.7, 14407.7, 14407.7, 14407.7, 14407.7, 14407.7, 14407.7, 14407.7, 14407.7, 14304.5, 14304.5, 14304.5, 14304.5, 14304.5, 14304.5, 14304.5, 14304.5, 14304.5, 14304.5, 14304.5, 14304.5, 14304.5, 14304.5, 14304.5, 14304.5, 14145.1, 14145.1, 14145.1, 14145.1, 14145.1, 14145.1, 14145.1, 14145.1, 14145.1, 14145.1, 14145.1, 14145.1, 14145.1, 14145.1, 14145.1, 14145.1, 14145.1, 14145.1, 14145.1, 14145.1, 14198.7, 14198.7, 14198.7, 14198.7, 14198.7, 14198.7, 14198.7, 14198.7, 14198.7, 14198.7, 14198.7, 14198.7, 14198.7, 14198.7, 14198.7, 14198.7, 14198.7, 14198.7, 14198.7, 14198.7, 14190.0, 14190.0, 14190.0, 14190.0, 14190.0, 14190.0, 14190.0, 14190.0, 14190.0, 14190.0, 14190.0, 14190.0, 14190.0, 14190.0, 14190.0, 14190.0, 14190.0, 14190.0, 14190.0, 14190.0, 14075.9, 14075.9, 14075.9, 14075.9, 14075.9, 14075.9, 14075.9, 14075.9, 14075.9, 14075.9, 14075.9, 14075.9, 14075.9, 14075.9, 14075.9, 14075.9, 14075.9, 14075.9, 14075.9, 14075.9, 14044.7, 14044.7, 14044.7, 14044.7, 14044.7, 14044.7, 14044.7, 14044.7, 14044.7, 14044.7, 14044.7, 14044.7, 14044.7, 14044.7, 14044.7, 14044.7, 14044.7, 14044.7, 14044.7, 14044.7, 13988.6, 13988.6, 13988.6, 13988.6, 13988.6, 13988.6, 13988.6, 13988.6, 13988.6, 13988.6, 13988.6, 13988.6, 13988.6, 13988.6, 13988.6, 13988.6, 13988.6, 13988.6, 13988.6, 13988.6, 13827.0, 13827.0, 13827.0, 13827.0, 13827.0, 13827.0, 13827.0, 13827.0, 13827.0, 13827.0, 13827.0, 13827.0, 13827.0, 13827.0, 13827.0, 13827.0, 13827.0, 13827.0, 13674.9, 13827.0, 13827.0, 13674.9, 13674.9, 13674.9, 13674.9, 13674.9, 13674.9, 13674.9, 13674.9, 13674.9, 13674.9, 13674.9, 13674.9, 13674.9, 13674.9, 13674.9, 13674.9, 13851.8, 13851.8, 13851.8, 13851.8, 13851.8, 13851.8, 13851.8, 13851.8, 13851.8, 13851.8, 13851.8, 13851.8, 13851.8, 13851.8, 13851.8, 13851.8, 13851.8, 13851.8, 13851.8, 13851.8, 14154.1, 14154.1, 14154.1, 14154.1, 14154.1, 14154.1, 14154.1, 14154.1, 14154.1, 14154.1, 14154.1, 14154.1, 14154.1, 14154.1, 14154.1, 14154.1, 14154.1, 14154.1, 14154.1, 14154.1, 14177.3, 14177.3, 14177.3, 14177.3, 14177.3, 14177.3, 14177.3, 14177.3, 14177.3, 14177.3, 14177.3, 14177.3, 14177.3, 14177.3, 14177.3, 14177.3, 14393.4, 14393.4, 14393.4, 14393.4, 14393.4, 14393.4, 14393.4, 14393.4, 14393.4, 14393.4, 14393.4, 14393.4, 14393.4, 14393.4, 14393.4, 14393.4, 14393.4, 14393.4, 14393.4, 14393.4, 14624.4, 14624.4, 14624.4, 14624.4, 14624.4, 14624.4, 14624.4, 14624.4, 14624.4, 14624.4, 14624.4, 14624.4, 14624.4, 14624.4, 14624.4, 14624.4, 14624.4, 14624.4, 14624.4, 14624.4, 14654.4, 14654.4, 14654.4, 14654.4, 14654.4, 14654.4, 14654.4, 14654.4, 14654.4, 14654.4, 14654.4, 14654.4, 14654.4, 14654.4, 14654.4, 14654.4, 14654.4, 14654.4, 14654.4, 14654.4, 14639.6, 14639.6, 14639.6, 14639.6, 14639.6, 14639.6, 14639.6, 14639.6, 14639.6, 14639.6, 14639.6, 14639.6, 14639.6, 14639.6, 14639.6, 14639.6, 14639.6, 14639.6, 14639.6, 14639.6, 14536.5, 14536.5, 14536.5, 14536.5, 14536.5, 14536.5, 14536.5, 14536.5, 14536.5, 14536.5, 14536.5, 14536.5, 14536.5, 14536.5, 14536.5, 14536.5, 14536.5, 14536.5, 14536.5, 14536.5, 14520.5, 14520.5, 14520.5, 14520.5, 14520.5, 14520.5, 14520.5, 14520.5, 14520.5, 14520.5, 14520.5, 14520.5, 14520.5, 14520.5, 14520.5, 14520.5, 14520 ...

# %%
sent_trace = go.Scatter(x=data['Time'], y=data['Sentiment'], name= 'Sentiment')
py.iplot([sent_trace])
# Out:
# <div id="6ee25d16-53a9-4dd8-bd27-6535ec0a4ff2" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("6ee25d16-53a9-4dd8-bd27-6535ec0a4ff2", [{"type": "scatter", "name": "Sentiment", "x": ["2017-12-09 17:00:00", "2017-12-09 17:00:00", "2017-12-09 17:00:00", "2017-12-09 17:00:00", "2017-12-09 17:01:00", "2017-12-09 17:01:00", "2017-12-09 17:01:00", "2017-12-09 17:01:00", "2017-12-09 17:02:00", "2017-12-09 17:02:00", "2017-12-09 17:02:00", "2017-12-09 17:02:00", "2017-12-09 17:03:00", "2017-12-09 17:03:00", "2017-12-09 17:03:00", "2017-12-09 17:03:00", "2017-12-09 17:04:00", "2017-12-09 17:04:00", "2017-12-09 17:04:00", "2017-12-09 17:04:00", "2017-12-09 17:05:00", "2017-12-09 17:05:00", "2017-12-09 17:05:00", "2017-12-09 17:05:00", "2017-12-09 17:06:00", "2017-12-09 17:06:00", "2017-12-09 17:06:00", "2017-12-09 17:06:00", "2017-12-09 17:07:00", "2017-12-09 17:07:00", "2017-12-09 17:07:00", "2017-12-09 17:07:00", "2017-12-09 17:08:00", "2017-12-09 17:08:00", "2017-12-09 17:08:00", "2017-12-09 17:08:00", "2017-12-09 17:09:00", "2017-12-09 17:09:00", "2017-12-09 17:09:00", "2017-12-09 17:09:00", "2017-12-09 17:10:00", "2017-12-09 17:10:00", "2017-12-09 17:10:00", "2017-12-09 17:10:00", "2017-12-09 17:11:00", "2017-12-09 17:11:00", "2017-12-09 17:11:00", "2017-12-09 17:12:00", "2017-12-09 17:12:00", "2017-12-09 17:12:00", "2017-12-09 17:12:00", "2017-12-09 17:13:00", "2017-12-09 17:13:00", "2017-12-09 17:13:00", "2017-12-09 17:13:00", "2017-12-09 17:14:00", "2017-12-09 17:14:00", "2017-12-09 17:14:00", "2017-12-09 17:14:00", "2017-12-09 17:15:00", "2017-12-09 17:15:00", "2017-12-09 17:15:00", "2017-12-09 17:15:00", "2017-12-09 17:16:00", "2017-12-09 17:16:00", "2017-12-09 17:16:00", "2017-12-09 17:16:00", "2017-12-09 17:17:00", "2017-12-09 17:17:00", "2017-12-09 17:17:00", "2017-12-09 17:17:00", "2017-12-09 17:18:00", "2017-12-09 17:18:00", "2017-12-09 17:18:00", "2017-12-09 17:18:00", "2017-12-09 17:19:00", "2017-12-09 17:19:00", "2017-12-09 17:19:00", "2017-12-09 17:19:00", "2017-12-09 17:20:00", "2017-12-09 17:20:00", "2017-12-09 17:20:00", "2017-12-09 17:20:00", "2017-12-09 17:21:00", "2017-12-09 17:21:00", "2017-12-09 17:21:00", "2017-12-09 17:21:00", "2017-12-09 17:22:00", "2017-12-09 17:22:00", "2017-12-09 17:22:00", "2017-12-09 17:22:00", "2017-12-09 17:23:00", "2017-12-09 17:23:00", "2017-12-09 17:23:00", "2017-12-09 17:23:00", "2017-12-09 17:24:00", "2017-12-09 17:24:00", "2017-12-09 17:24:00", "2017-12-09 17:25:00", "2017-12-09 17:25:00", "2017-12-09 17:25:00", "2017-12-09 17:25:00", "2017-12-09 17:26:00", "2017-12-09 17:26:00", "2017-12-09 17:26:00", "2017-12-09 17:26:00", "2017-12-09 17:27:00", "2017-12-09 17:27:00", "2017-12-09 17:27:00", "2017-12-09 17:27:00", "2017-12-09 17:28:00", "2017-12-09 17:28:00", "2017-12-09 17:28:00", "2017-12-09 17:28:00", "2017-12-09 17:29:00", "2017-12-09 17:29:00", "2017-12-09 17:29:00", "2017-12-09 17:29:00", "2017-12-09 17:30:00", "2017-12-09 17:30:00", "2017-12-09 17:30:00", "2017-12-09 17:30:00", "2017-12-09 17:31:00", "2017-12-09 17:31:00", "2017-12-09 17:31:00", "2017-12-09 17:31:00", "2017-12-09 17:32:00", "2017-12-09 17:32:00", "2017-12-09 17:32:00", "2017-12-09 17:32:00", "2017-12-09 17:33:00", "2017-12-09 17:33:00", "2017-12-09 17:33:00", "2017-12-09 17:33:00", "2017-12-09 17:34:00", "2017-12-09 17:34:00", "2017-12-09 17:34:00", "2017-12-09 17:34:00", "2017-12-09 17:35:00", "2017-12-09 17:35:00", "2017-12-09 17:35:00", "2017-12-09 17:35:00", "2017-12-09 17:36:00", "2017-12-09 17:36:00", "2017-12-09 17:36:00", "2017-12-09 17:36:00", "2017-12-09 17:37:00", "2017-12-09 17:37:00", "2017-12-09 17:37:00", "2017-12-09 17:37:00", "2017-12-09 17:38:00", "2017-12-09 17:38:00", "2017-12-09 17:38:00", "2017-12-09 17:38:00", "2017-12-09 17:39:00", "2017-12-09 17:39:00", "2017-12-09 17:39:00", "2017-12-09 17:39: ...

# %%
datag = data[['Price','Sentiment']].groupby(data['Time']).mean()

# %% [markdown]
# ## Training a simple random model:

# %%
from sklearn.preprocessing import MinMaxScaler
values = datag['Price'].values.reshape(-1,1)
sentiment = datag['Sentiment'].values.reshape(-1,1)
values = values.astype('float32')
sentiment = sentiment.astype('float32')
scaler = MinMaxScaler(feature_range=(0, 1))
scaled = scaler.fit_transform(values)

# %%
train_size = int(len(scaled) * 0.7)
test_size = len(scaled) - train_size
train, test = scaled[0:train_size,:], scaled[train_size:len(scaled),:]
print(len(train), len(test))
split = train_size
# Out:
# 2523 1082

# %%
def create_dataset(dataset, look_back, sentiment, sent=False):
    dataX, dataY = [], []
    for i in range(len(dataset) - look_back):
        if i >= look_back:
            a = dataset[i-look_back:i+1, 0]
            a = a.tolist()
            if(sent==True):
                a.append(sentiment[i].tolist()[0])
            dataX.append(a)
            dataY.append(dataset[i + look_back, 0])
    #print(len(dataY))
    return np.array(dataX), np.array(dataY)

# %% [markdown]
# ### with lookback = 1 (kind of unigram)

# %%
look_back = 1
trainX, trainY = create_dataset(train, look_back, sentiment[0:train_size])
testX, testY = create_dataset(test, look_back, sentiment[train_size:len(scaled)])

# %%
trainX = np.reshape(trainX, (trainX.shape[0], 1, trainX.shape[1]))
testX = np.reshape(testX, (testX.shape[0], 1, testX.shape[1]))

# %%
model = Sequential()
model.add(LSTM(100, input_shape=(trainX.shape[1], trainX.shape[2])))
model.add(Dense(1))
model.compile(loss='mae', optimizer='adam')
history = model.fit(trainX, trainY, epochs=300, batch_size=100, validation_data=(testX, testY), verbose=0, shuffle=False)

# %%
yhat = model.predict(testX)
pyplot.plot(yhat, label='predict')
pyplot.plot(testY, label='true')
pyplot.legend()
pyplot.show()

# %%
yhat_inverse_1 = scaler.inverse_transform(yhat.reshape(-1, 1))
testY_inverse_1 = scaler.inverse_transform(testY.reshape(-1, 1))

# %%
rmse_1 = sqrt(mean_squared_error(testY_inverse_1, yhat_inverse_1))
print('Test RMSE: %.3f' % rmse_1)
# Out:
# Test RMSE: 60.814

# %%
model_1 = model

# %% [markdown]
# ### with lookback = 2(kind of biram)

# %%
look_back = 2
trainX, trainY = create_dataset(train, look_back, sentiment[0:train_size])
testX, testY = create_dataset(test, look_back, sentiment[train_size:len(scaled)])

# %%
trainX = np.reshape(trainX, (trainX.shape[0], 1, trainX.shape[1]))
testX = np.reshape(testX, (testX.shape[0], 1, testX.shape[1]))

# %%
model = Sequential()
model.add(LSTM(100, input_shape=(trainX.shape[1], trainX.shape[2])))
model.add(Dense(1))
model.compile(loss='mae', optimizer='adam')
history = model.fit(trainX, trainY, epochs=300, batch_size=100, validation_data=(testX, testY), verbose=0, shuffle=False)

# %%
yhat = model.predict(testX)
pyplot.plot(yhat, label='predict')
pyplot.plot(testY, label='true')
pyplot.legend()
pyplot.show()
# Out:
# <img src="data:image/png;base64,..." width="431.7499871328477">

# %%
yhat_inverse_2 = scaler.inverse_transform(yhat.reshape(-1, 1))
testY_inverse_2 = scaler.inverse_transform(testY.reshape(-1, 1))

# %%
rmse_2 = sqrt(mean_squared_error(testY_inverse_2, yhat_inverse_2))
print('Test RMSE: %.3f' % rmse_2)
# Out:
# Test RMSE: 47.262

# %%
model2 = model

# %% [markdown]
# ## With lookback = 3

# %%
look_back = 3
trainX, trainY = create_dataset(train, look_back, sentiment[0:train_size])
testX, testY = create_dataset(test, look_back, sentiment[train_size:len(scaled)])
# Out:
# 2517
# 1076

# %%
trainX = np.reshape(trainX, (trainX.shape[0], 1, trainX.shape[1]))
testX = np.reshape(testX, (testX.shape[0], 1, testX.shape[1]))

# %%
model = Sequential()
model.add(LSTM(100, input_shape=(trainX.shape[1], trainX.shape[2])))
model.add(Dense(1))
model.compile(loss='mae', optimizer='adam')
history = model.fit(trainX, trainY, epochs=300, batch_size=100, validation_data=(testX, testY), verbose=0, shuffle=False)

# %%
yhat = model.predict(testX)
pyplot.plot(yhat, label='predict')
pyplot.plot(testY, label='true')
pyplot.legend()
pyplot.show()

# %%
yhat_inverse_3 = scaler.inverse_transform(yhat.reshape(-1, 1))
testY_inverse_3 = scaler.inverse_transform(testY.reshape(-1, 1))

# %%
rmse_3 = sqrt(mean_squared_error(testY_inverse_3, yhat_inverse_3))
print('Test RMSE: %.3f' % rmse_3)
# Out:
# Test RMSE: 60.197

# %%
model3 = model

# %% [markdown]
# ## Plotting different lookups

# %%
pyplot.plot(yhat_inverse_1, label='predict_lookup_1')
pyplot.plot(yhat_inverse_2, label='predict_lookup_1')
pyplot.plot(yhat_inverse_3, label='predict_lookup_1')
pyplot.plot(testY_inverse_3, label='true')
pyplot.legend()
pyplot.show()

# %%
len(datag.index.values)
# Out:
# 3605

# %%
btc_1_trace = go.Scatter(x=datag.index.values[3605-1080-1:], y=yhat_inverse_1.reshape(1080), name= 'predict_lookup_1')
btc_2_trace = go.Scatter(x=datag.index.values[3605-1078-1:], y=yhat_inverse_2.reshape(1078), name= 'predict_lookup_2')
btc_3_trace = go.Scatter(x=datag.index.values[3605-1076-1:], y=yhat_inverse_3.reshape(1076), name= 'predict_lookup_3')
btc_t_trace = go.Scatter(x=datag.index.values[3605-1080-1:], y=testY_inverse_1.reshape(1080), name= 'True')

py.iplot([btc_1_trace,btc_2_trace, btc_3_trace, btc_t_trace])
# Out:
# <div id="41a2c483-6a0e-46d8-8078-4928f0e3f482" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("41a2c483-6a0e-46d8-8078-4928f0e3f482", [{"type": "scatter", "name": "predict_lookup_1", "x": ["2017-12-11 19:54:00", "2017-12-11 19:55:00", "2017-12-11 19:56:00", "2017-12-11 19:57:00", "2017-12-11 19:58:00", "2017-12-11 19:59:00", "2017-12-11 20:00:00", "2017-12-11 20:01:00", "2017-12-11 20:02:00", "2017-12-11 20:03:00", "2017-12-11 20:04:00", "2017-12-11 20:05:00", "2017-12-11 20:06:00", "2017-12-11 20:07:00", "2017-12-11 20:08:00", "2017-12-11 20:09:00", "2017-12-11 20:10:00", "2017-12-11 20:11:00", "2017-12-11 20:12:00", "2017-12-11 20:13:00", "2017-12-11 20:14:00", "2017-12-11 20:15:00", "2017-12-11 20:16:00", "2017-12-11 20:17:00", "2017-12-11 20:18:00", "2017-12-11 20:19:00", "2017-12-11 20:20:00", "2017-12-11 20:21:00", "2017-12-11 20:22:00", "2017-12-11 20:23:00", "2017-12-11 20:24:00", "2017-12-11 20:25:00", "2017-12-11 20:26:00", "2017-12-11 20:27:00", "2017-12-11 20:28:00", "2017-12-11 20:29:00", "2017-12-11 20:30:00", "2017-12-11 20:31:00", "2017-12-11 20:32:00", "2017-12-11 20:33:00", "2017-12-11 20:34:00", "2017-12-11 20:35:00", "2017-12-11 20:36:00", "2017-12-11 20:37:00", "2017-12-11 20:38:00", "2017-12-11 20:39:00", "2017-12-11 20:40:00", "2017-12-11 20:41:00", "2017-12-11 20:42:00", "2017-12-11 20:43:00", "2017-12-11 20:44:00", "2017-12-11 20:45:00", "2017-12-11 20:46:00", "2017-12-11 20:47:00", "2017-12-11 20:48:00", "2017-12-11 20:49:00", "2017-12-11 20:50:00", "2017-12-11 20:51:00", "2017-12-11 20:52:00", "2017-12-11 20:53:00", "2017-12-11 20:54:00", "2017-12-11 20:55:00", "2017-12-11 20:56:00", "2017-12-11 20:57:00", "2017-12-11 20:58:00", "2017-12-11 20:59:00", "2017-12-11 21:00:00", "2017-12-11 21:01:00", "2017-12-11 21:02:00", "2017-12-11 21:03:00", "2017-12-11 21:04:00", "2017-12-11 21:06:00", "2017-12-11 21:07:00", "2017-12-11 21:08:00", "2017-12-11 21:09:00", "2017-12-11 21:10:00", "2017-12-11 21:11:00", "2017-12-11 21:12:00", "2017-12-11 21:13:00", "2017-12-11 21:14:00", "2017-12-11 21:15:00", "2017-12-11 21:16:00", "2017-12-11 21:17:00", "2017-12-11 21:18:00", "2017-12-11 21:19:00", "2017-12-11 21:20:00", "2017-12-11 21:21:00", "2017-12-11 21:22:00", "2017-12-11 21:23:00", "2017-12-11 21:24:00", "2017-12-11 21:25:00", "2017-12-11 21:26:00", "2017-12-11 21:27:00", "2017-12-11 21:28:00", "2017-12-11 21:29:00", "2017-12-11 21:30:00", "2017-12-11 21:31:00", "2017-12-11 21:32:00", "2017-12-11 21:33:00", "2017-12-11 21:34:00", "2017-12-11 21:35:00", "2017-12-11 21:36:00", "2017-12-11 21:37:00", "2017-12-11 21:38:00", "2017-12-11 21:39:00", "2017-12-11 21:40:00", "2017-12-11 21:41:00", "2017-12-11 21:42:00", "2017-12-11 21:43:00", "2017-12-11 21:44:00", "2017-12-11 21:45:00", "2017-12-11 21:46:00", "2017-12-11 21:47:00", "2017-12-11 21:48:00", "2017-12-11 21:49:00", "2017-12-11 21:50:00", "2017-12-11 21:51:00", "2017-12-11 21:52:00", "2017-12-11 21:53:00", "2017-12-11 21:54:00", "2017-12-11 21:55:00", "2017-12-11 21:56:00", "2017-12-11 21:57:00", "2017-12-11 21:58:00", "2017-12-11 21:59:00", "2017-12-11 22:00:00", "2017-12-11 22:01:00", "2017-12-11 22:02:00", "2017-12-11 22:03:00", "2017-12-11 22:04:00", "2017-12-11 22:05:00", "2017-12-11 22:06:00", "2017-12-11 22:07:00", "2017-12-11 22:08:00", "2017-12-11 22:09:00", "2017-12-11 22:10:00", "2017-12-11 22:11:00", "2017-12-11 22:12:00", "2017-12-11 22:13:00", "2017-12-11 22:14:00", "2017-12-11 22:15:00", "2017-12-11 22:16:00", "2017-12-11 22:17:00", "2017-12-11 22:18:00", "2017-12-11 22:19:00", "2017-12-11 22:20:00", "2017-12-11 22:21:00", "2017-12-11 22:22:00", "2017-12-11 22:23:00", "2017-12-11 22:24:00", "2017-12-11 22:25:00", "2017-12-11 22:26:00", "2017-12-11 22:27:00", "2017-12-11 22:28:00", "2017-12-11 22:29:00", "2017-12-11 22:30:00", "2017-12-11 22:31:00", "2017-12-11 ...

# %% [markdown]
# # With sentiment and lookup2

# %%
look_back = 2
trainX, trainY = create_dataset(train, look_back, sentiment[0:train_size],sent=True)
testX, testY = create_dataset(test, look_back, sentiment[train_size:len(scaled)], sent=True)

# %%
trainX = np.reshape(trainX, (trainX.shape[0], 1, trainX.shape[1]))
testX = np.reshape(testX, (testX.shape[0], 1, testX.shape[1]))

# %%
model = Sequential()
model.add(LSTM(100, input_shape=(trainX.shape[1], trainX.shape[2]), return_sequences=True))
model.add(LSTM(100))
model.add(Dense(1))
model.compile(loss='mae', optimizer='adam')
history = model.fit(trainX, trainY, epochs=300, batch_size=100, validation_data=(testX, testY), verbose=0, shuffle=False)

# %%
yhat = model.predict(testX)
pyplot.plot(yhat, label='predict')
pyplot.plot(testY, label='true')
pyplot.legend()
pyplot.show()

# %%
yhat_inverse_sent = scaler.inverse_transform(yhat.reshape(-1, 1))
testY_inverse_sent = scaler.inverse_transform(testY.reshape(-1, 1))

# %%
rmse_sent = sqrt(mean_squared_error(testY_inverse_sent, yhat_inverse_sent))
print('Test RMSE: %.3f' % rmse_sent)
# Out:
# Test RMSE: 44.563

# %%
len(yhat)

# %%
btc_1_trace = go.Scatter(x=datag.index.values[3605-1078-1:][0:500], y=yhat_inverse_sent.reshape(1078)[0:500], name= 'With_Sentiment')
btc_2_trace = go.Scatter(x=datag.index.values[3605-1080-1:][0:500], y=yhat_inverse_1.reshape(1080)[0:500], name= 'No_Sentiment')
btc_3_trace = go.Scatter(x=datag.index.values[3605-1078-1:][0:500], y=testY_inverse_sent.reshape(1078)[0:500], name= 'True')
py.iplot([btc_1_trace,btc_2_trace,btc_3_trace])
# Out:
# <div id="9c8d550f-975a-46f5-ac6e-89cae0912797" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("9c8d550f-975a-46f5-ac6e-89cae0912797", [{"type": "scatter", "y": [17108.673828125, 17118.673828125, 17121.150390625, 17121.169921875, 17128.908203125, 17141.6640625, 17151.34765625, 17156.109375, 17156.140625, 17178.42578125, 17214.89453125, 17242.7890625, 17256.3984375, 17256.3984375, 17258.751953125, 17267.302734375, 17273.2421875, 17277.5546875, 17277.5546875, 17274.802734375, 17264.7421875, 17257.771484375, 17252.642578125, 17252.63671875, 17252.853515625, 17305.8984375, 17339.611328125, 17372.021484375, 17371.8984375, 17372.056640625, 17428.630859375, 17464.5390625, 17499.13671875, 17499.13671875, 17498.826171875, 17497.224609375, 17496.205078125, 17495.2265625, 17495.2265625, 17495.2265625, 17508.697265625, 17517.267578125, 17525.517578125, 17525.34765625, 17525.25390625, 17529.8828125, 17534.373046875, 17538.146484375, 17539.04296875, 17538.42578125, 17477.544921875, 17418.28515625, 17367.974609375, 17355.658203125, 17365.3671875, 17375.310546875, 17383.54296875, 17385.546875, 17385.552734375, 17384.05078125, 17382.71875, 17381.5859375, 17381.3046875, 17381.3046875, 17383.970703125, 17393.978515625, 17400.76953125, 17405.857421875, 17406.03125, 17398.44140625, 17370.33984375, 17350.947265625, 17336.69140625, 17330.353515625, 17307.361328125, 17291.37109375, 17279.703125, 17279.767578125, 17287.173828125, 17314.0546875, 17332.734375, 17346.291015625, 17346.291015625, 17346.328125, 17337.234375, 17331.42578125, 17325.873046875, 17325.873046875, 17325.904296875, 17262.294921875, 17221.759765625, 17182.78515625, 17182.78515625, 17182.818359375, 17174.595703125, 17169.341796875, 17164.291015625, 17164.291015625, 17164.3046875, 17192.83984375, 17210.93359375, 17228.353515625, 17228.3359375, 17228.3359375, 17240.06640625, 17251.43359375, 17261.1015625, 17263.494140625, 17275.646484375, 17295.51953125, 17310.666015625, 17318.083984375, 17318.083984375, 17307.001953125, 17288.865234375, 17275.056640625, 17268.29296875, 17268.2734375, 17292.431640625, 17331.94140625, 17362.05078125, 17377.125, 17377.072265625, 17379.734375, 17384.06640625, 17387.388671875, 17388.99609375, 17389.19140625, 17382.986328125, 17360.44140625, 17344.86328125, 17333.529296875, 17333.529296875, 17330.630859375, 17320.0078125, 17312.646484375, 17307.2890625, 17307.2890625, 17301.6875, 17281.3046875, 17267.095703125, 17256.8125, 17256.80859375, 17256.80859375, 17239.375, 17228.216796875, 17217.501953125, 17217.517578125, 17217.517578125, 17233.685546875, 17249.38671875, 17262.673828125, 17265.986328125, 17265.986328125, 17250.4375, 17235.3203125, 17222.4765625, 17219.296875, 17219.296875, 17209.763671875, 17200.50390625, 17192.634765625, 17190.685546875, 17228.24609375, 17252.171875, 17275.09375, 17275.09375, 17252.90625, 17216.611328125, 17188.921875, 17175.267578125, 17175.25390625, 17178.291015625, 17183.23828125, 17187.009765625, 17188.859375, 17188.859375, 17198.572265625, 17214.443359375, 17226.552734375, 17232.486328125, 17232.486328125, 17217.638671875, 17193.3359375, 17174.810546875, 17165.71484375, 17165.71484375, 17164.90625, 17161.966796875, 17159.931640625, 17158.44921875, 17158.44921875, 17165.017578125, 17188.85546875, 17205.330078125, 17217.357421875, 17217.259765625, 17214.158203125, 17202.8828125, 17195.068359375, 17189.40234375, 17189.40234375, 17189.40234375, 17210.43359375, 17223.8046875, 17236.69140625, 17236.67578125, 17236.67578125, 17230.265625, 17224.064453125, 17218.783203125, 17217.505859375, 17217.505859375, 17165.740234375, 17115.53515625, 17072.8125, 17062.20703125, 17062.20703125, 17040.0546875, 17018.59375, 17000.337890625, 16995.81640625, 16980.767578125, 16966.189453125, 16953.78515625, 16950.71484375, 16950.71484375, 16954.703125, 16961.222656 ...

# %%
model_sent = model

# %% [markdown]
# ## Now go live with the model:

# %%
import MySQLdb
#Enter the values for you database connection
dsn_database = "bitcoin"         # e.g. "MySQLdbtest"
dsn_hostname = "173.194.231.244"      # e.g.: "mydbinstance.xyz.us-east-1.rds.amazonaws.com"
dsn_port = 3306                  # e.g. 3306 
dsn_uid = "demo"             # e.g. "user1"
dsn_pwd = "qwerty@123"              # e.g. "Password123"

# %%
conn = MySQLdb.connect(host=dsn_hostname, port=dsn_port, user=dsn_uid, passwd=dsn_pwd, db=dsn_database)

# %%
cursor=conn.cursor()
cursor.execute("""SELECT * FROM live_data""")
cursor.fetchone()
# Out:
# (1234.0, 123.0, 456.0, datetime.date(2009, 2, 2))

# %%
print ("\nShow me the records:\n")
rows = cursor.fetchall()
import pprint
pprint.pprint(rows)
# Out:
# Show me the records:
#
# ()

# %%
cursor.execute("""INSERT INTO live_data values(15625,16000,0.8,'1000-01-01 00:00:00');""")
# Out:
# 1

# %%
conn.commit()

# %%
cursor.close()

# %%
# develop a real time pipeline

# %%
import queue 
import time
import matplotlib

# %%
matplotlib.__version__
# Out:
# '2.1.0'

# %%
import queue
import matplotlib.pyplot as plt
true_q = queue.Queue()
pred_q = queue.Queue()
'''
fig = plt.figure()
ax = fig.add_subplot(111)
fig.show()
fig.canvas.draw()
plt.ion()
'''

def process_data(in_data):
    out_data = []
    for line in in_data:
        out_data.append(float(line.split(',')[0]))
    return np.array(out_data).reshape(-1,1)
prev = 15000
threshold = 0.5
while True:
    btc = open('live_bitcoin.csv','r')
    sent = open('live_tweet.csv','r')
    bit_data = btc.readlines()
    sent_data = sent.readlines()
    bit_data = process_data(bit_data[len(bit_data)-5:])
    sent_data = process_data(sent_data[len(sent_data)-5:])
    live = scaler.transform(bit_data)
    testX, testY = create_dataset(live, 2, sent_data, sent=True)
    testX = np.reshape(testX, (testX.shape[0], 1, testX.shape[1]))
    yhat = model.predict(testX)
    yhat_inverse = scaler.inverse_transform(yhat.reshape(-1, 1))
    true_q.put(bit_data[4])
    pred_q.put(yhat_inverse[0])
    val = 100*((yhat_inverse[0][0] - prev)/prev)
    if val > threshold:
        decision = 'buy'
    elif val <-threshold:
        decision = 'sell'
    else:
        decision = ''
    prev = yhat_inverse[0][0]
    input_string = "INSERT INTO live_data values ({},{},{},'{}','{}');".format(yhat_inverse[0][0],bit_data[0][0],sent_data[4][0],datetime.datetime.now().strftime('%Y-%m-%d %H:%M:%S '),decision)
    cursor.execute(input_string)
    conn.commit()
    time.sleep(60)
    '''
    if true_q.qsize() > 9:
        true_q.get()
        pred_q.get()
        ax.clear()
        ax.plot()
        ax.plot(list(true_q.queue),'-',label='True')
        ax.plot(list(pred_q.queue),'--',label='Predict')
        ax.legend()
        fig.canvas.draw()
        time.sleep(60)
    '''
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-84-4afc19f662f3> in <module>()
#      43     cursor.execute(input_string)
#      44     conn.commit()
# ---> 45     time.sleep(60)
#      46     '''
#      47     if true_q.qsize() > 9:
#
# KeyboardInterrupt:

# %%
import datetime
datetime.datetime.now()
# Out:
# datetime.datetime(2017, 12, 13, 21, 49, 54, 337601)
